# %%
import pandas as pd

df = pd.read_csv("Train.csv")
df
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0                 1.0            Low          4.0  Cat_4            D
# ...

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#           ID  Gender Ever_Married  Age Graduated     Profession  \
# 0     462809    Male           No   22        No     Healthcare
# 1     462643  Female          Yes   38       Yes       Engineer
# 2     466315  Female          Yes   67       Yes       Engineer
# 3     461735    Male          Yes   67       Yes         Lawyer
# 4     462669  Female          Yes   40       Yes  Entertainment
# ...      ...     ...          ...  ...       ...            ...
# 8063  464018    Male           No   22        No            NaN
# 8064  464685    Male           No   35        No      Executive
# 8065  465406  Female           No   33       Yes     Healthcare
# 8066  467299  Female           No   27       Yes     Healthcare
# 8067  461879    Male          Yes   37       Yes      Executive
#
#       Work_Experience Spending_Score  Family_Size  Var_1
# 0                 1.0            Low          4.0  Cat_4
# 1                 NaN        Average          3.0  Cat_4
# ...

# %%
y = df.iloc[:,10]

# %%
y
# Out:
# 0       D
# 1       A
# 2       B
# 3       B
# 4       A
#        ..
# 8063    D
# 8064    D
# 8065    D
# 8066    B
# 8067    B
# Name: Segmentation, Length: 8068, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Le_x = LabelEncoder()

# %%
x = x.apply(LabelEncoder().fit_transform)

# %%
x
# Out:
#         ID  Gender  Ever_Married  Age  Graduated  Profession  Work_Experience  \
# 0     3441       1             0    4          0           5                1
# 1     3292       0             1   18          1           2               15
# 2     6571       0             1   44          1           2                1
# 3     2469       1             1   44          1           7                0
# 4     3315       0             1   20          1           3               15
# ...    ...     ...           ...  ...        ...         ...              ...
# 8063  4525       1             0    4          0           9                0
# 8064  5130       1             0   15          0           4                3
# 8065  5754       0             0   14          1           5                1
# 8066  7461       0             0    8          1           5                1
# 8067  2601       1             1   17          1           4                0
#
# ...

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
import numpy as np

# %%
dtf = DecisionTreeClassifier()

# %%
dtf.fit(x.iloc[:,0:10],y)
# Out:
# DecisionTreeClassifier()

# %%
xinput = np.array([1,1,17,1,4,0,0,2,3,6])

# %%
y_predict = dtf.predict([xinput])

# %%
y_predict
# Out:
# array(['A'], dtype=object)

# %%
xinput = np.array([3441,1,0,4,0,5,1,2,3,3])

# %%
y_predict = dtf.predict([xinput])

# %%
y_predict
# Out:
# array(['D'], dtype=object)

# %%
xinput = np.array([2469,1,1,44,1,7,0,1,1,5])

# %%
y_predict = dtf.predict([xinput])

# %%
y_predict
# Out:
# array(['B'], dtype=object)

# %%
b = a.iloc[: , 1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c21ab0be35cb> in <module>
# ----> 1 b = a.iloc[: , 1:]
#
# NameError: name 'a' is not defined
